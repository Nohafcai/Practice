# %% [markdown]
# <a href="https://colab.research.google.com/github/Nohafcai/Practice/blob/main/groupby.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://www.propublica.org/datastore/dataset/congressional-data-bulk-legislation-bills
# Out:
# Downloading...
# From: https://www.propublica.org/datastore/dataset/congressional-data-bulk-legislation-bills
# To: /content/congressional-data-bulk-legislation-bills
# 30.0kB [00:00, 235MB/s]

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/congressional-data-bulk-legislation-bills')
df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-3-bb0ba2649464> in <cell line: 1>()
# ----> 1 df = pd.read_csv('/content/congressional-data-bulk-legislation-bills')
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
# prompt: read this path /content/legislators-current.csv using pandas

df_legislators = pd.read_csv('/content/legislators-current.csv')
df_legislators
# Out:
#      last_name first_name middle_name suffix nickname              full_name  \
# 0        Brown    Sherrod         NaN    NaN      NaN          Sherrod Brown
# 1     Cantwell      Maria         NaN    NaN      NaN         Maria Cantwell
# 2       Cardin   Benjamin          L.    NaN      NaN     Benjamin L. Cardin
# 3       Carper     Thomas     Richard    NaN      NaN       Thomas R. Carper
# 4        Casey     Robert          P.    Jr.      Bob   Robert P. Casey, Jr.
# ..         ...        ...         ...    ...      ...                    ...
# 534   Ricketts       Pete         NaN    NaN      NaN          Pete Ricketts
# 535  McClellan   Jennifer         NaN    NaN      NaN  Jennifer L. McClellan
# 536     Butler   Laphonza   Romanique    NaN      NaN     Laphonza R. Butler
# 537        Amo       Gabe         NaN    NaN      NaN               Gabe Amo
# 538      Maloy    Celeste         NaN    NaN      NaN                    NaN
#
# ...

# %%
df_legislators.keys()
# Out:
# Index(['last_name', 'first_name', 'middle_name', 'suffix', 'nickname',
#        'full_name', 'birthday', 'gender', 'type', 'state', 'district',
#        'senate_class', 'party', 'url', 'address', 'phone', 'contact_form',
#        'rss_url', 'twitter', 'twitter_id', 'facebook', 'youtube', 'youtube_id',
#        'mastodon', 'bioguide_id', 'thomas_id', 'opensecrets_id', 'lis_id',
#        'fec_ids', 'cspan_id', 'govtrack_id', 'votesmart_id', 'ballotpedia_id',
#        'washington_post_id', 'icpsr_id', 'wikipedia_id'],
#       dtype='object')

# %%
df_legislators['state'].unique() , df_legislators['state'].nunique()
# Out:
# (array(['OH', 'WA', 'MD', 'DE', 'PA', 'MN', 'NJ', 'VT', 'MI', 'MT', 'RI',
#         'WY', 'MS', 'ME', 'TX', 'IL', 'SC', 'KY', 'OR', 'ID', 'NH', 'VA',
#         'NY', 'WV', 'AL', 'WI', 'CO', 'FL', 'GA', 'TN', 'CT', 'AR', 'IN',
#         'CA', 'LA', 'MO', 'OK', 'NC', 'AZ', 'IA', 'NM', 'HI', 'ND', 'MA',
#         'UT', 'KS', 'AK', 'DC', 'MP', 'NE', 'SD', 'NV', 'VI', 'AS', 'PR',
#         'GU'], dtype=object),
#  56)

# %%
by_state = df_legislators.groupby('state', group_keys=True)

# %%
for state, frame in by_state:
     print(f"First 2 entries for {state!r}")
     print("------------------------")
     print(frame, end="\n\n")
# Out:
# First 2 entries for 'AK'
# ------------------------
#      last_name first_name middle_name suffix nickname             full_name  \
# 114  Murkowski       Lisa          A.    NaN      NaN        Lisa Murkowski
# 253   Sullivan        Dan         NaN    NaN      NaN          Dan Sullivan
# 453    Peltola       Mary     Sattler    NaN      NaN  Mary Sattler Peltola
#
#        birthday gender type state  ...  opensecrets_id  lis_id    fec_ids  \
# 114  1957-05-22      F  sen    AK  ...       N00026050    S288  S4AK00099
# 253  1964-11-13      M  sen    AK  ...       N00035774    S383  S4AK00214
# 453  1973-08-31      F  rep    AK  ...       N00050780     NaN  H2AK01158
#
#       cspan_id govtrack_id votesmart_id      ballotpedia_id  \
# 114  1004138.0      300075      15841.0      Lisa Murkowski
# 253  1023262.0      412665     114964.0  Daniel S. Sullivan
# 453        NaN      456870     207620.0        Mary Peltola
#
#     washington_post_id icpsr_id                 wikipedia_id
# ...
